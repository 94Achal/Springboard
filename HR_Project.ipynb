# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

# %% [markdown]
# # Importing Train Dataset

# %%
train_dataset = pd.read_csv("train.csv")
train_dataset
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# 5            58896          Analytics   region_2        Bachelor's      m
# 6            20379         Operations  region_20        Bachelor's      f
# 7            16290         Operations  region_34  Master's & above      m
# 8            73202          Analytics  region_20        Bachelor's      m
# 9            28911  Sales & Marketing   region_1  Master's & above      m
# 10           29934         Technology  region_23               NaN      m
# 11           49017  Sales & Marketing   region_7        Bachelor's      f
# ...

# %% [markdown]
# # Data pre-processing

# %%
#Filling the missing data with MODE
train_dataset = train_dataset.fillna(train_dataset.mode().iloc[0])
HR_dataset = train_dataset.iloc[:,6:13].values
HR_predict = train_dataset.iloc[:,13].values
HR_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# # Applying Logistic Regression

# %%
LogReg = LogisticRegression()
LogReg.fit(HR_dataset,HR_predict)
print (LogReg.score(HR_dataset, HR_predict))
# Out:
# C:\Users\Achal94\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.9164538023646183

# %% [markdown]
# # Evaluating model on Train Data

# %%
y_pred = LogReg.predict(HR_dataset)
print(classification_report(HR_predict,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     50140
#            1       0.59      0.06      0.11      4668
#
#    micro avg       0.92      0.92      0.92     54808
#    macro avg       0.76      0.53      0.53     54808
# weighted avg       0.89      0.92      0.88     54808

# %% [markdown]
# # Importing Test Data

# %%
test_dataset = pd.read_csv('test.csv')
test_dataset
# Out:
#        employee_id         department     region         education gender  \
# 0             8724         Technology  region_26        Bachelor's      m
# 1            74430                 HR   region_4        Bachelor's      f
# 2            72255  Sales & Marketing  region_13        Bachelor's      m
# 3            38562        Procurement   region_2        Bachelor's      f
# 4            64486            Finance  region_29        Bachelor's      m
# 5            46232        Procurement   region_7        Bachelor's      m
# 6            54542            Finance   region_2        Bachelor's      m
# 7            67269          Analytics  region_22        Bachelor's      m
# 8            66174         Technology   region_7  Master's & above      m
# 9            76303         Technology  region_22        Bachelor's      m
# 10           60245  Sales & Marketing  region_16        Bachelor's      m
# 11           42639  Sales & Marketing  region_17  Master's & above      m
# ...

# %%
test_dataset = test_dataset.fillna(test_dataset.mode().iloc[0])
HR_dataset = test_dataset.iloc[:,6:13].values
HR_dataset
# Out:
# array([[ 1., 24.,  3., ...,  1.,  0., 77.],
#        [ 1., 31.,  3., ...,  0.,  0., 51.],
#        [ 1., 31.,  1., ...,  0.,  0., 47.],
#        ...,
#        [ 1., 26.,  4., ...,  0.,  0., 50.],
#        [ 3., 27.,  3., ...,  0.,  0., 70.],
#        [ 3., 40.,  5., ...,  1.,  0., 89.]])

# %%
print(len(HR_dataset))
# Out:
# 23490

# %%
test_pred = LogReg.predict(HR_dataset)
test_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# # Importing Sample Submission

# %%
sample_dataset= pd.read_csv("sample_submission_M0L0uXE.csv")

# %%
y_true=sample_dataset.iloc[:,1].values
y_true
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# # Calculating F1 score

# %%
f1_score(y_true,test_pred,average='weighted')
# Out:
# C:\Users\Achal94\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# 0.9955958438448711
